# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('../data/external/complaints-2023-10-24_23_29.csv')

# %%
df.head()
# Out:
#   Date received                                            Product  \
# 0      01/05/23  Credit reporting, credit repair services, or o...
# 1      12/27/21                                    Debt collection
# 2      04/19/21  Credit reporting, credit repair services, or o...
# 3      07/04/23                        Checking or savings account
# 4      07/20/23                                           Mortgage
#
#                   Sub-product  \
# 0            Credit reporting
# 1            Credit card debt
# 2            Credit reporting
# 3             Savings account
# 4  Conventional home mortgage
#
#                                                Issue  \
# 0  Problem with a credit reporting company's inve...
# 1                  Attempts to collect debt not owed
# 2  Problem with a credit reporting company's inve...
# 3                                Managing an account
# 4                     Trouble during payment process
#
#                                            Sub-issue  \
# 0  Was not notified of investigation status or re...
# 1                  Debt was result of identity theft
# 2         Problem with personal statement of dispute
# 3                           Deposits and withdrawals
# 4                                               None
#
#                         Consumer complaint narrative  \
# 0  I retrieved a copy of my credit report and imm...
# 1  this message is for USAA. i reported to them t...
# 2  To whom it may concern, i was working on refin...
# 3  During year XXXX I loaned funds from my person...
# 4  This is a response and continuation of complai...
#
#                              Company public response  \
# 0                                               None
# 1  Company believes it acted appropriately as aut...
# 2  Company has responded to the consumer and the ...
# 3                                               None
# 4                                               None
#
#                                   Company State ZIP code           Tags  \
# 0                         HW Holding, Inc    GA    30297           None
# 1  UNITED SERVICES AUTOMOBILE ASSOCIATION    NC    283XX  Servicemember
# 2            TRUIST FINANCIAL CORPORATION    FL    33160           None
# 3           SAN DIEGO COUNTY CREDIT UNION    CA    92596           None
# 4                      Fay Servicing, LLC    CA    92887           None
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0           Consent provided           Web             01/05/23
# 1           Consent provided           Web             12/27/21
# 2           Consent provided           Web             04/19/21
# 3           Consent provided           Web             07/06/23
# 4           Consent provided           Web             07/20/23
#
#   Company response to consumer Timely response? Consumer disputed?  \
# 0      Closed with explanation              Yes                NaN
# 1      Closed with explanation              Yes                NaN
# 2      Closed with explanation              Yes                NaN
# 3      Closed with explanation              Yes                NaN
# 4      Closed with explanation              Yes                NaN
#
#    Complaint ID
# 0     6402405.0
# 1     5045906.0
# 2     4309183.0
# 3     7204114.0
# 4     7280737.0

# %%
df.shape
# Out:
# (1386068, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1386068 entries, 0 to 1386067
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count    Dtype
# ---  ------                        --------------    -----
#  0   Date received                 1386068 non-null  object
#  1   Product                       1386068 non-null  object
#  2   Sub-product                   1386068 non-null  object
#  3   Issue                         1386068 non-null  object
#  4   Sub-issue                     1386068 non-null  object
#  5   Consumer complaint narrative  1386067 non-null  object
#  6   Company public response       1386067 non-null  object
#  7   Company                       1386067 non-null  object
#  8   State                         1386067 non-null  object
#  9   ZIP code                      1386067 non-null  object
#  10  Tags                          1386067 non-null  object
#  11  Consumer consent provided?    1386067 non-null  object
#  12  Submitted via                 1386067 non-null  object
#  13  Date sent to company          1386067 non-null  object
#  14  Company response to consumer  1386067 non-null  object
#  15  Timely response?              1386067 non-null  object
#  16  Consumer disputed?            80585 non-null    object
#  17  Complaint ID                  1386067 non-null  float64
# dtypes: float64(1), object(17)
# memory usage: 190.3+ MB

# %%
df.Product.unique()
# Out:
# array(['Credit reporting, credit repair services, or other personal consumer reports',
#        'Debt collection', 'Checking or savings account', 'Mortgage',
#        'Credit card or prepaid card', 'Vehicle loan or lease',
#        'Payday loan, title loan, or personal loan', 'Student loan',
#        'Money transfer, virtual currency, or money service'], dtype=object)
